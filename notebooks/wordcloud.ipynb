# %%
# %pip install pillow

# %%
# %pip install wordcloud

# %% [markdown]
# mensajes positivos negativos de productos
# que tiene el dataset

# %%
import pandas as pd
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
