# %% [markdown]
# # Notebook: WordClouds y Análisis de Longitudes (Guía)
#
# ## 1) Objetivos
# - Explorar la distribución de longitudes de los textos del dataset.
# - Generar nubes de palabras (WordClouds) para ver las palabras más frecuentes.
# - Preparar artefactos (imágenes y csv) para la documentación del proyecto.
#
# ---
#
# ## 2) Cargar librerías e instalar recursos
# ```python
# # Cargar librerías
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from wordcloud import WordCloud
# import spacy
# import nltk
#
# # Descargas necesarias (ejecutar una vez)
# # !python -m spacy download es_core_news_sm
# # import nltk
# # nltk.download('stopwords')
# # nltk.download('punkt')
# ```
#
# ## 3) Cargar datos
# ```python
# df = pd.read_csv("data/processed/mi_dataset_procesado.csv")
# df.head()
# ```
#
# ## 4) Preprocesado del texto
# - Pasa a minúsculas, elimina URLs/menciones/hashtags, lematiza, quita stopwords.
# - Usa spaCy para lematizar en español.
#
# ```python
# # Usa la función 'clean_text' del script de ejemplo o define aquí la tuya
# ```
#
# ## 5) WordCloud general y por etiqueta (si aplica)
# ```python
# # Genera la nube general y, si tienes etiquetas (p. ej. 'hate', 'neutral'), genera una nube por cada clase.
# ```
#
# ## 6) Análisis de longitudes
# ```python
# # Calcular número de tokens, histograma y boxplot
# ```
#
# ## 7) Exportar resultados
# - Guardar imágenes en outputs/wordclouds y outputs/plots
# - Exportar top palabras a CSV

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import spacy
import nltk
